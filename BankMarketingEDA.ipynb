# %% [markdown]
# **Name: Shatabdi Pal**  Email: shatabdi@pdx.edu Country: USA

# %% [markdown]
# **Mounting Google Drive for the dataset**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import warnings
# Suppress all warnings
warnings.simplefilter("ignore")

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **Reading the Dataset**

# %%
bank_full_df =pd.read_csv('/content/drive/MyDrive/Internship/bank+marketing/bank/bank-full.csv', sep=';')
print(bank_full_df.shape)
print(bank_full_df.info())
# print(bank_full_df.head())
# Out:
# (45211, 17)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB
# None

# %%
bank_df = pd.read_csv('/content/drive/MyDrive/Internship/bank+marketing/bank/bank.csv',sep=';')
print(bank_df.shape)
print(bank_df.info())
print(bank_df.head())
# Out:
# (4521, 17)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4521 entries, 0 to 4520
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        4521 non-null   int64
#  1   job        4521 non-null   object
#  2   marital    4521 non-null   object
#  3   education  4521 non-null   object
#  4   default    4521 non-null   object
#  5   balance    4521 non-null   int64
#  6   housing    4521 non-null   object
#  7   loan       4521 non-null   object
#  8   contact    4521 non-null   object
#  9   day        4521 non-null   int64
#  10  month      4521 non-null   object
#  11  duration   4521 non-null   int64
#  12  campaign   4521 non-null   int64
#  13  pdays      4521 non-null   int64
#  14  previous   4521 non-null   int64
#  15  poutcome   4521 non-null   object
#  16  y          4521 non-null   object
# dtypes: int64(7), object(10)
# memory usage: 600.6+ KB
# None
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
bank_additional_full_df = pd.read_csv('/content/drive/MyDrive/Internship/bank+marketing/bank-additional/bank-additional-full.csv',sep=';')
print(bank_additional_full_df.shape)
print(bank_additional_full_df.info())
print(bank_additional_full_df.head())
# Out:
# (41188, 21)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
#  17  cons.conf.idx   41188 non-null  float64
#  18  euribor3m       41188 non-null  float64
#  19  nr.employed     41188 non-null  float64
#  20  y               41188 non-null  object
# dtypes: float64(5), int64(5), object(11)
# memory usage: 6.6+ MB
# None
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          93.994          -36.4      4.857       5191.0  no
# 1          93.994          -36.4      4.857       5191.0  no
# 2          93.994          -36.4      4.857       5191.0  no
# 3          93.994          -36.4      4.857       5191.0  no
# 4          93.994          -36.4      4.857       5191.0  no
#
# [5 rows x 21 columns]

# %%
bank_additional_df = pd.read_csv('/content/drive/MyDrive/Internship/bank+marketing/bank-additional/bank-additional.csv',sep=';')
print(bank_additional_df.shape)
print(bank_additional_df.info())
print(bank_additional_df.head())
# Out:
# (4119, 21)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4119 entries, 0 to 4118
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             4119 non-null   int64
#  1   job             4119 non-null   object
#  2   marital         4119 non-null   object
#  3   education       4119 non-null   object
#  4   default         4119 non-null   object
#  5   housing         4119 non-null   object
#  6   loan            4119 non-null   object
#  7   contact         4119 non-null   object
#  8   month           4119 non-null   object
#  9   day_of_week     4119 non-null   object
#  10  duration        4119 non-null   int64
#  11  campaign        4119 non-null   int64
#  12  pdays           4119 non-null   int64
#  13  previous        4119 non-null   int64
#  14  poutcome        4119 non-null   object
#  15  emp.var.rate    4119 non-null   float64
#  16  cons.price.idx  4119 non-null   float64
#  17  cons.conf.idx   4119 non-null   float64
#  18  euribor3m       4119 non-null   float64
#  19  nr.employed     4119 non-null   float64
#  20  y               4119 non-null   object
# dtypes: float64(5), int64(5), object(11)
# memory usage: 675.9+ KB
# None
#    age          job  marital          education default  housing     loan  \
# 0   30  blue-collar  married           basic.9y      no      yes       no
# 1   39     services   single        high.school      no       no       no
# 2   25     services  married        high.school      no      yes       no
# 3   38     services  married           basic.9y      no  unknown  unknown
# 4   47       admin.  married  university.degree      no      yes       no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0   cellular   may         fri  ...         2    999         0  nonexistent
# 1  telephone   may         fri  ...         4    999         0  nonexistent
# 2  telephone   jun         wed  ...         1    999         0  nonexistent
# 3  telephone   jun         fri  ...         3    999         0  nonexistent
# 4   cellular   nov         mon  ...         1    999         0  nonexistent
#
#   emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0         -1.8          92.893          -46.2      1.313       5099.1  no
# 1          1.1          93.994          -36.4      4.855       5191.0  no
# 2          1.4          94.465          -41.8      4.962       5228.1  no
# 3          1.4          94.465          -41.8      4.959       5228.1  no
# 4         -0.1          93.200          -42.0      4.191       5195.8  no
#
# [5 rows x 21 columns]

# %% [markdown]
# **Data Exploration**

# %% [markdown]
# **Checking for Null values**

# %%
# Count of NaN values per column
nan_count = bank_additional_full_df.isna().sum()
print("Count of NaN values per column:")
print(nan_count)
# Out:
# Count of NaN values per column:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %% [markdown]
# **Checking if bank_additional_df is a subset of bank_additional_full_df**

# %%
# Check if bank_additional_df is a subset of bank_additional_full_df
is_subset = bank_additional_df.isin(bank_additional_full_df).all().all()

if is_subset:
    print("bank_additional_df is a subset of bank_additional_full_df")
else:
    print("bank_additional_df is not a subset of bank_additional_full_df")
# Out:
# bank_additional_df is not a subset of bank_additional_full_df

# %% [markdown]
# **Merging data frames bank_additional_df, bank_additional_full_df**

# %%
# Concatenate both datasets vertically
combined_df = pd.concat([bank_additional_df, bank_additional_full_df], ignore_index=True)

# Verify the shape of the combined DataFrame
print("Shape of combined DataFrame:", combined_df.shape)

# Display the first few rows of the combined DataFrame
print(combined_df.head())
# Out:
# Shape of combined DataFrame: (45307, 21)
#    age          job  marital          education default  housing     loan  \
# 0   30  blue-collar  married           basic.9y      no      yes       no
# 1   39     services   single        high.school      no       no       no
# 2   25     services  married        high.school      no      yes       no
# 3   38     services  married           basic.9y      no  unknown  unknown
# 4   47       admin.  married  university.degree      no      yes       no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0   cellular   may         fri  ...         2    999         0  nonexistent
# 1  telephone   may         fri  ...         4    999         0  nonexistent
# 2  telephone   jun         wed  ...         1    999         0  nonexistent
# 3  telephone   jun         fri  ...         3    999         0  nonexistent
# 4   cellular   nov         mon  ...         1    999         0  nonexistent
#
#   emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0         -1.8          92.893          -46.2      1.313       5099.1  no
# 1          1.1          93.994          -36.4      4.855       5191.0  no
# 2          1.4          94.465          -41.8      4.962       5228.1  no
# 3          1.4          94.465          -41.8      4.959       5228.1  no
# 4         -0.1          93.200          -42.0      4.191       5195.8  no
#
# [5 rows x 21 columns]

# %% [markdown]
# **Checking for duplicate records in merged dataframe and removing duplicates if any**

# %%
# Check for duplicates across all columns
duplicates = combined_df[combined_df.duplicated()]

# Check based on specific columns (all columns)
duplicates_specific = combined_df[combined_df.duplicated(subset=combined_df.columns.tolist())]

# Print count of duplicates
if duplicates_specific.empty:
    print("No duplicate rows found.")
else:
    print("Duplicate rows found:")
    print("Total count:", len(duplicates_specific))

# Drop duplicate records based on all columns
final_df = combined_df.drop_duplicates()

# Print shape of deduplicated DataFrame to verify
print("Shape of deduplicated DataFrame:", final_df.shape)
# Out:
# Duplicate rows found:
# Total count: 4131
# Shape of deduplicated DataFrame: (41176, 21)

# %% [markdown]
# **Checking for uniques values in final dataset**

# %%
# Get distinct count for each feature
#distinct_counts = df.nunique()
for column in final_df.columns:
    distinct_values = final_df[column].unique()
    distinct_count = len(distinct_values)
    print(f"Feature: {column}")
    print(f"Distinct Count: {distinct_count}")
    print(f"Distinct Values: {distinct_values}")
    print()
# Out:
# Feature: age
# Distinct Count: 78
# Distinct Values: [30 39 25 38 47 32 41 31 35 36 29 27 44 46 45 50 55 40 28 34 33 51 48 20
#  76 56 24 58 60 37 52 42 49 54 59 57 43 53 75 82 71 21 22 23 26 81 61 67
#  73 18 64 74 77 86 85 63 88 78 72 68 80 66 19 62 65 69 70 95 79 83 17 87
#  91 98 94 84 92 89]
#
# Feature: job
# Distinct Count: 12
# Distinct Values: ['blue-collar' 'services' 'admin.' 'entrepreneur' 'self-employed'
#  'technician' 'management' 'student' 'retired' 'housemaid' 'unemployed'
#  'unknown']
#
# Feature: marital
# Distinct Count: 4
# Distinct Values: ['married' 'single' 'divorced' 'unknown']
#
# Feature: education
# Distinct Count: 8
# Distinct Values: ['basic.9y' 'high.school' 'university.degree' 'professional.course'
#  'basic.6y' 'basic.4y' 'unknown' 'illiterate']
#
# Feature: default
# Distinct Count: 3
# Distinct Values: ['no' 'unknown' 'yes']
#
# Feature: housing
# Distinct Count: 3
# Distinct Values: ['yes' 'no' 'unknown']
#
# Feature: loan
# Distinct Count: 3
# Distinct Values: ['no' 'unknown' 'yes']
#
# Feature: contact
# Distinct Count: 2
# Distinct Values: ['cellular' 'telephone']
#
# Feature: month
# Distinct Count: 10
# Distinct Values: ['may' 'jun' 'nov' 'sep' 'jul' 'aug' 'mar' 'oct' 'apr' 'dec']
#
# Feature: day_of_week
# Distinct Count: 5
# Distinct Values: ['fri' 'wed' 'mon' 'thu' 'tue']
#
# Feature: duration
# Distinct Count: 1544
# Distinct Values: [ 487  346  227 ... 1616 1246 1556]
#
# Feature: campaign
# Distinct Count: 42
# Distinct Values: [ 2  4  1  3  6  7 27  5 12 14 10  8 11 13  9 15 16 18 17 22 19 23 24 35
#  29 25 20 56 39 42 28 26 32 21 31 30 41 37 40 33 34 43]
#
# Feature: pdays
# Distinct Count: 27
# Distinct Values: [999  12   3   6   5   2  10  11   7   1  18   4  15   0  16   9  19  17
#   13  21  14   8  22  25  26  27  20]
#
# Feature: previous
# Distinct Count: 8
# Distinct Values: [0 2 1 3 5 4 6 7]
#
# Feature: poutcome
# Distinct Count: 3
# Distinct Values: ['nonexistent' 'failure' 'success']
#
# Feature: emp.var.rate
# Distinct Count: 10
# Distinct Values: [-1.8  1.1  1.4 -0.1 -1.1 -2.9 -1.7 -3.4 -3.  -0.2]
#
# Feature: cons.price.idx
# Distinct Count: 26
# Distinct Values: [92.893 93.994 94.465 93.2   94.199 93.918 93.444 93.369 92.843 92.963
#  94.601 94.027 92.379 92.431 93.749 93.075 94.055 92.469 94.767 92.201
#  92.649 94.215 93.876 93.798 92.713 92.756]
#
# Feature: cons.conf.idx
# Distinct Count: 26
# Distinct Values: [-46.2 -36.4 -41.8 -42.  -37.5 -42.7 -36.1 -34.8 -50.  -40.8 -49.5 -38.3
#  -29.8 -26.9 -34.6 -47.1 -39.8 -33.6 -50.8 -31.4 -30.1 -40.3 -40.  -40.4
#  -33.  -45.9]
#
# Feature: euribor3m
# Distinct Count: 316
# Distinct Values: [1.313 4.855 4.962 4.959 4.191 0.884 0.879 4.153 4.958 4.968 4.859 4.963
#  4.957 4.965 4.961 0.639 4.967 4.864 4.856 1.299 4.86  1.687 4.865 1.268
#  4.12  1.334 0.977 1.344 0.899 1.327 4.592 4.97  1.26  4.966 0.77  4.866
#  4.964 4.857 0.886 0.739 0.654 1.405 1.281 4.96  0.754 1.291 1.365 4.076
#  1.266 1.41  1.25  4.858 0.702 1.029 1.085 1.392 1.262 1.05  0.851 0.716
#  0.877 0.835 1.048 0.904 1.028 0.637 1.244 1.354 4.021 1.453 0.715 1.778
#  0.773 1.035 0.9   0.898 0.742 0.861 1.264 0.704 1.27  0.695 1.039 1.531
#  0.883 0.748 0.809 4.794 1.479 0.697 0.959 1.032 0.896 0.827 1.483 0.905
#  1.466 0.714 0.644 0.849 0.881 0.834 0.645 0.659 0.885 1.041 0.942 0.737
#  4.947 0.722 1.049 1.415 0.797 0.699 0.81  0.71  1.423 0.707 0.646 1.043
#  4.955 0.668 0.825 1.435 0.72  0.767 0.982 1.602 1.259 1.811 0.859 1.224
#  0.876 0.878 1.099 0.788 0.717 0.838 0.64  0.762 1.663 0.73  0.728 1.372
#  0.782 4.245 1.51  3.329 0.749 4.343 0.893 0.731 0.635 0.7   0.889 0.649
#  0.873 1.445 1.629 0.944 3.853 0.87  0.79  5.045 0.914 0.719 0.735 1.498
#  0.677 0.819 0.652 0.692 0.829 1.726 1.406 0.761 0.846 1.252 4.956 0.953
#  0.803 0.937 0.706 0.869 1.703 0.729 0.709 1.046 0.752 0.921 4.921 0.987
#  1.03  1.031 0.741 0.843 1.044 0.643 0.755 0.724 0.882 1.757 1.215 0.74
#  0.683 1.52  4.663 1.059 0.636 0.771 0.655 1.4   0.65  1.384 0.778 0.682
#  1.614 1.04  1.538 1.072 1.    1.799 1.64  1.65  0.642 0.718 0.768 0.723
#  0.996 0.721 0.672 0.854 1.016 0.965 5.    4.936 4.918 4.912 4.827 4.76
#  4.733 4.7   4.474 4.406 4.286 4.223 3.901 3.879 3.816 3.743 3.669 3.563
#  3.488 3.428 3.282 3.053 1.584 1.574 1.56  1.556 1.548 1.286 1.235 1.206
#  1.018 1.007 0.979 0.969 0.933 0.927 0.908 0.903 0.821 0.813 0.781 0.766
#  0.743 0.75  0.753 0.744 0.733 0.712 0.708 0.653 0.651 0.634 0.638 0.663
#  0.684 0.685 0.688 0.69  0.701 0.711 0.713 0.727 0.732 0.793 0.802 0.822
#  0.84  0.895 0.894 0.891 0.89  0.888 0.88  0.956 0.972 0.985 0.993 1.008
#  1.025 1.037 1.045 1.047]
#
# Feature: nr.employed
# Distinct Count: 11
# Distinct Values: [5099.1 5191.  5228.1 5195.8 4963.6 5008.7 5076.2 4991.6 5017.5 5023.5
#  5176.3]
#
# Feature: y
# Distinct Count: 2
# Distinct Values: ['no' 'yes']

# %% [markdown]
# **"unknown" values in final dataset**

# %%
# Check for 'unknown' values in each column
unknowns = final_df.isin(['unknown']).any()

# Print columns with 'unknown' values
columns_with_unknown = unknowns[unknowns].index.tolist()
print(f"Columns with 'unknown' values: {columns_with_unknown}")
# Out:
# Columns with 'unknown' values: ['job', 'marital', 'education', 'default', 'housing', 'loan']

# %%
# Calculate the percentage of 'unknown' values in each column

unknown_percentages = (final_df.isin(['unknown'])).mean() * 100
# Print the percentage of 'unknown' values for each relevant column
for column in columns_with_unknown:
    print(f"Percentage of 'unknown' values in {column}: {unknown_percentages[column]:.2f}%")
# Out:
# Percentage of 'unknown' values in job: 0.80%
# Percentage of 'unknown' values in marital: 0.19%
# Percentage of 'unknown' values in education: 4.20%
# Percentage of 'unknown' values in default: 20.88%
# Percentage of 'unknown' values in housing: 2.40%
# Percentage of 'unknown' values in loan: 2.40%

# %% [markdown]
# **Technique 1: Impute with most frequent value**

# %%
# for column in unknowns[unknowns].index:
#     most_frequent = final_df[column].mode()[0]
#     print(most_frequent)
#     final_df[column] = final_df[column].replace('unknown', most_frequent)

from scipy import stats
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestClassifier


def impute_most_frequent(df, columns_with_unknown):
    df_imputed = df.copy()
    for column in columns_with_unknown:
          if 'unknown' in df_imputed[column].values:
              imputer = SimpleImputer(strategy='most_frequent')
              df_imputed[column] = imputer.fit_transform(df_imputed[[column]]).ravel()
    return df_imputed

# %% [markdown]
# **Technique 2: Impute using Randomforest model**

# %%
# Function to impute missing values using RandomForestClassifier
def impute_random_forest(df, columns_with_unknown):
    df_imputed = df.copy()

    for column in columns_with_unknown:
        if df_imputed[column].isna().any():
            known_data = df_imputed[df_imputed[column].notna()]
            unknown_data = df_imputed[df_imputed[column].isna()]

            X_train = known_data.drop(columns=[column])
            y_train = known_data[column]

            X_test = unknown_data.drop(columns=[column])

            model = RandomForestClassifier(n_estimators=100, random_state=42)
            model.fit(X_train, y_train)

            predicted_values = model.predict(X_test)
            df_imputed.loc[df_imputed[column].isna(), column] = predicted_values

    return df_imputed

# %% [markdown]
# **comaparison of both method**

# %%
# Function to perform KS test
def ks_test(df1, df2, columns_with_unknown):
    ks_stats = {}

    for column in columns_with_unknown: # Iterate over the list
        ks_stat, p_value = stats.ks_2samp(df1[column].dropna(), df2[column].dropna())
        ks_stats[column] = (ks_stat, p_value)

    return ks_stats

# Impute missing values using different methods
df1 = final_df.copy()
df2 = final_df.copy()
imputed_most_frequent = impute_most_frequent(df1, columns_with_unknown)
imputed_rf = impute_random_forest(df2, columns_with_unknown)

# Perform KS test to compare distributions
ks_stats = ks_test(imputed_most_frequent, imputed_rf, columns_with_unknown)

# Print KS statistics and p-values
for column, (ks_stat, p_value) in ks_stats.items():
    print(f"Column: {column}, KS Statistic: {ks_stat}, p-value: {p_value}")
# Out:
# Column: job, KS Statistic: 0.0, p-value: 1.0
# Column: marital, KS Statistic: 0.0, p-value: 1.0
# Column: education, KS Statistic: 0.0, p-value: 1.0
# Column: default, KS Statistic: 0.0, p-value: 1.0
# Column: housing, KS Statistic: 0.0, p-value: 1.0
# Column: loan, KS Statistic: 0.0, p-value: 1.0

# %% [markdown]
# **Impute with most frequent value**

# %%
for column in unknowns[unknowns].index:
    most_frequent = final_df[column].mode()[0]
    print(most_frequent)
    final_df[column] = final_df[column].replace('unknown', most_frequent)
# Out:
# admin.
# married
# university.degree
# no
# yes
# no

# %% [markdown]
# **Checking if there is any imbalance in dataset**

# %%
#count the number of y by each type
final_df.groupby('y').size()
# Out:
# y
# no     36537
# yes     4639
# dtype: int64

# %% [markdown]
# **Distribution of numerical features for checking skewness**

# %%
import matplotlib.pyplot as plt
import seaborn as sns


#Identify Numerical and Non-Numerical Columns
numerical_columns = final_df.select_dtypes(include=['int64', 'float64']).columns
non_numerical_columns = final_df.select_dtypes(include=['object', 'string', 'category']).columns

features = numerical_columns.tolist();
# Plot Histograms in Subplots
num_features = len(features)
num_plots_per_row = 3
num_rows = (num_features // num_plots_per_row) + (num_features % num_plots_per_row > 0)

fig, axes = plt.subplots(num_rows, num_plots_per_row, figsize=(20, 5 * num_rows))

# Flatten axes array if more than one row
if num_rows > 1:
    axes = axes.flatten()
else:
    axes = [axes]

for ax, feature in zip(axes, features):
    sns.histplot(final_df[feature], bins=30, kde=True, ax=ax)
    ax.set_title(f'Distribution of {feature}')
    ax.set_xlabel(feature)
    ax.set_ylabel('Frequency')

# Remove any empty subplots
for i in range(num_features, len(axes)):
    fig.delaxes(axes[i])

plt.tight_layout()
plt.show()

# %% [markdown]
# **Boxplot for checking outlier in numerical features**

# %%
#Plot Boxplots in Subplots
num_features = len(features)
num_plots_per_row = 3
num_rows = (num_features // num_plots_per_row) + (num_features % num_plots_per_row > 0)

fig, axes = plt.subplots(num_rows, num_plots_per_row, figsize=(10, 4 * num_rows))

# Flatten axes array if more than one row
if num_rows > 1:
    axes = axes.flatten()
else:
    axes = [axes]

for ax, feature in zip(axes, features):
    sns.boxplot(y=final_df[feature], ax=ax)
    ax.set_title(f'Boxplot of {feature}')
    ax.set_xlabel(feature)
    ax.set_ylabel('Values')

# Remove any empty subplots
for i in range(num_features, len(axes)):
    fig.delaxes(axes[i])

plt.tight_layout()
plt.show()

# %% [markdown]
# **Technique 1 outlier handling using Z score**

# %%
df3 = final_df[numerical_columns].copy()
# Function to detect outliers using Z-score
def detect_outliers_zscore(df, threshold=3):
    outliers = pd.DataFrame()

    for column in df.columns:
        z_scores = np.abs((df[column] - df[column].mean()) / df[column].std())
        column_outliers = df[z_scores > threshold]
        column_outliers['Outlier_ZScore_' + column] = z_scores[z_scores > threshold]
        outliers = pd.concat([outliers, column_outliers], axis=1)

    return outliers

# Detect outliers using Z-score method
outliers_zscore = detect_outliers_zscore(df3)

print("Outliers detected using Z-score:")
print(outliers_zscore)
# Out:
# Outliers detected using Z-score:
#         age  duration  campaign  pdays  previous  emp.var.rate  \
# 42     76.0     126.0       1.0  999.0       1.0          -1.7
# 128    75.0     109.0       1.0  999.0       1.0          -1.8
# 150    82.0     279.0       3.0    3.0       2.0          -1.1
# 228    76.0     347.0       4.0    6.0       1.0          -3.4
# 338    81.0     617.0       2.0  999.0       0.0          -1.8
# ...     ...       ...       ...    ...       ...           ...
# 45261   NaN       NaN       NaN    NaN       NaN           NaN
# 45263   NaN       NaN       NaN    NaN       NaN           NaN
# 45289   NaN       NaN       NaN    NaN       NaN           NaN
# 45292   NaN       NaN       NaN    NaN       NaN           NaN
# 45294   NaN       NaN       NaN    NaN       NaN           NaN
#
#        cons.price.idx  cons.conf.idx  euribor3m  nr.employed  ...  duration  \
# 42             94.027          -38.3      0.899       4991.6  ...       NaN
# 128            93.075          -47.1      1.405       5099.1  ...       NaN
# 150            94.199          -37.5      0.877       4963.6  ...       NaN
# 228            92.649          -30.1      0.715       5017.5  ...       NaN
# 338            92.893          -46.2      1.354       5099.1  ...       NaN
# ...               ...            ...        ...          ...  ...       ...
# 45261             NaN            NaN        NaN          NaN  ...       NaN
# 45263             NaN            NaN        NaN          NaN  ...       NaN
# 45289             NaN            NaN        NaN          NaN  ...       NaN
# 45292             NaN            NaN        NaN          NaN  ...       NaN
# 45294             NaN            NaN        NaN          NaN  ...       NaN
#
#        campaign  pdays  previous  emp.var.rate  cons.price.idx  cons.conf.idx  \
# 42          NaN    NaN       NaN           NaN             NaN            NaN
# 128         NaN    NaN       NaN           NaN             NaN            NaN
# 150         NaN    NaN       NaN           NaN             NaN            NaN
# 228         NaN    NaN       NaN           NaN             NaN            NaN
# 338         NaN    NaN       NaN           NaN             NaN            NaN
# ...         ...    ...       ...           ...             ...            ...
# 45261       NaN    NaN       NaN           NaN             NaN            NaN
# 45263       NaN    NaN       NaN           NaN             NaN            NaN
# 45289       NaN    NaN       NaN           NaN             NaN            NaN
# 45292       NaN    NaN       NaN           NaN             NaN            NaN
# 45294       NaN    NaN       NaN           NaN             NaN            NaN
#
#        euribor3m  nr.employed  Outlier_ZScore_nr.employed
# 42           NaN          NaN                         NaN
# 128          NaN          NaN                         NaN
# 150          NaN          NaN                         NaN
# 228          NaN          NaN                         NaN
# 338          NaN          NaN                         NaN
# ...          ...          ...                         ...
# 45261        NaN          NaN                         NaN
# 45263        NaN          NaN                         NaN
# 45289        NaN          NaN                         NaN
# 45292        NaN          NaN                         NaN
# 45294        NaN          NaN                         NaN
#
# [3874 rows x 110 columns]

# %% [markdown]
# **Technique 2 outlier handling using IQR**

# %%
df4 = final_df[numerical_columns].copy()
# Function to detect outliers using IQR
def detect_outliers_iqr(df, threshold=1.5):
    outliers = pd.DataFrame()

    for column in df.columns:
        Q1 = df[column].quantile(0.25)
        Q3 = df[column].quantile(0.75)
        IQR = Q3 - Q1
        column_outliers = df[(df[column] < Q1 - threshold * IQR) | (df[column] > Q3 + threshold * IQR)]
        column_outliers['Outlier_IQR_' + column] = True
        outliers = pd.concat([outliers, column_outliers], axis=1)

    return outliers

# Detect outliers using IQR method
outliers_iqr = detect_outliers_iqr(df4)

print("\nOutliers detected using IQR:")
print(outliers_iqr)
# Out:
# Outliers detected using IQR:
#         age duration  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 42     76.0    126.0       1.0  999.0       1.0          -1.7          94.027
# 128    75.0    109.0       1.0  999.0       1.0          -1.8          93.075
# 150    82.0    279.0       3.0    3.0       2.0          -1.1          94.199
# 167    71.0    224.0       1.0  999.0       0.0          -1.7          94.027
# 228    76.0    347.0       4.0    6.0       1.0          -3.4          92.649
# ...     ...      ...       ...    ...       ...           ...             ...
# 42712   NaN      NaN       NaN    NaN       NaN           NaN             NaN
# 42713   NaN      NaN       NaN    NaN       NaN           NaN             NaN
# 42715   NaN      NaN       NaN    NaN       NaN           NaN             NaN
# 42716   NaN      NaN       NaN    NaN       NaN           NaN             NaN
# 42717   NaN      NaN       NaN    NaN       NaN           NaN             NaN
#
#        cons.conf.idx  euribor3m  nr.employed  ... duration  campaign  pdays  \
# 42             -38.3      0.899       4991.6  ...      NaN       NaN    NaN
# 128            -47.1      1.405       5099.1  ...      NaN       NaN    NaN
# 150            -37.5      0.877       4963.6  ...      NaN       NaN    NaN
# 167            -38.3      0.904       4991.6  ...      NaN       NaN    NaN
# 228            -30.1      0.715       5017.5  ...      NaN       NaN    NaN
# ...              ...        ...          ...  ...      ...       ...    ...
# 42712            NaN        NaN          NaN  ...      NaN       NaN    NaN
# 42713            NaN        NaN          NaN  ...      NaN       NaN    NaN
# 42715            NaN        NaN          NaN  ...      NaN       NaN    NaN
# 42716            NaN        NaN          NaN  ...      NaN       NaN    NaN
# 42717            NaN        NaN          NaN  ...      NaN       NaN    NaN
#
#        previous  emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 42          NaN           NaN             NaN            NaN        NaN
# 128         NaN           NaN             NaN            NaN        NaN
# 150         NaN           NaN             NaN            NaN        NaN
# 167         NaN           NaN             NaN            NaN        NaN
# 228         NaN           NaN             NaN            NaN        NaN
# ...         ...           ...             ...            ...        ...
# 42712       NaN           NaN             NaN            NaN        NaN
# 42713       NaN           NaN             NaN            NaN        NaN
# 42715       NaN           NaN             NaN            NaN        NaN
# 42716       NaN           NaN             NaN            NaN        NaN
# 42717       NaN           NaN             NaN            NaN        NaN
#
#        nr.employed  Outlier_IQR_nr.employed
# 42             NaN                      NaN
# 128            NaN                      NaN
# 150            NaN                      NaN
# 167            NaN                      NaN
# 228            NaN                      NaN
# ...            ...                      ...
# 42712          NaN                      NaN
# 42713          NaN                      NaN
# 42715          NaN                      NaN
# 42716          NaN                      NaN
# 42717          NaN                      NaN
#
# [10827 rows x 110 columns]

# %%
# !pip install scikit-learn
import sklearn.metrics

# Get the common indices of outliers
common_indices = outliers_zscore.index.intersection(outliers_iqr.index)

# Subset the outlier DataFrames using the common indices
outliers_zscore_common = outliers_zscore.loc[common_indices]
outliers_iqr_common = outliers_iqr.loc[common_indices]

# Calculate Cohen's Kappa on the subsetted DataFrames
kappa = sklearn.metrics.cohen_kappa_score(outliers_zscore_common.index, outliers_iqr_common.index)
print("Cohen's Kappa coefficient (on common indices):", kappa)
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.25.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Cohen's Kappa coefficient (on common indices): 1.0

# %% [markdown]
# **outlier handling using IQR**

# %%
# Detect outliers using IQR method
outliers_iqr = detect_outliers_iqr(final_df[numerical_columns])

# %% [markdown]
# **Barplots for non numerical features**

# %%
# Add the 'y' Column to Non-Numerical DataFrame
non_numerical_df = final_df[non_numerical_columns].copy()
non_numerical_df['y'] = final_df['y']

# Plot Non-Numerical Data in Subgraphs
num_cols = len(non_numerical_columns)
num_plots_per_row = 3
num_rows = (num_cols // num_plots_per_row) + (num_cols % num_plots_per_row > 0)

fig, axes = plt.subplots(num_rows, num_plots_per_row, figsize=(20, 5 * num_rows))

# Flatten axes array if more than one row
if num_rows > 1:
    axes = axes.flatten()
else:
    axes = [axes]

for ax, col in zip(axes, non_numerical_columns):
    sns.countplot(data=non_numerical_df, x=col, hue='y', ax=ax)
    ax.set_title(f'{col} vs y')
    ax.set_xlabel(col)
    ax.set_ylabel('Count')
    ax.legend(title='y')

# Remove any empty subplots
for i in range(num_cols, len(axes)):
    fig.delaxes(axes[i])

plt.tight_layout()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# **Correlation between the features**

# %%
# Create DataFrames for Numerical and Non-Numerical Data
numerical_df = final_df[numerical_columns].copy()


#Calculate Correlation Matrices for Numerical Columns
numerical_corr = numerical_df.corr()

# Plot Heatmaps for Numerical Data Correlation
plt.figure(figsize=(8, 5))
sns.heatmap(numerical_corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap of Numerical Features with Target "y"')
plt.show()

# %% [markdown]
# **Multivariable analysis**

# %%
# Group the data by 'campaign' and calculate the subscription rate for each group
contact_subscription = final_df.groupby('campaign')['y'].value_counts(normalize=True).unstack().fillna(0)['yes']

# Plot the subscription rate against the number of contacts
plt.figure(figsize=(10, 6))
plt.plot(contact_subscription.index, contact_subscription.values, marker='o')
plt.title('Impact of Total Number of Contacts on Subscription')
plt.xlabel('Number of Contacts')
plt.ylabel('Subscription Rate')
plt.grid(True)
plt.show()

# %%
# Define the social and economic context attributes
attributes = ['emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed']

# Plotting box plots for each attribute
plt.figure(figsize=(10, 8))

for i, attribute in enumerate(attributes, start=1):
    plt.subplot(3, 2, i)
    sns.boxplot(x='y', y=attribute, data=final_df, palette='Set2')
    plt.title(f'{attribute.capitalize()} vs Subscription')
    plt.xlabel('Subscription')
    plt.ylabel(attribute.capitalize())

plt.tight_layout()
plt.show()

# %%
# Define the social and economic context attributes
attributes = ['emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed']

# Plotting violin plots for each attribute
plt.figure(figsize=(16, 10))

for i, attribute in enumerate(attributes, start=1):
    plt.subplot(3, 2, i)
    sns.violinplot(x='y', y=attribute, data=final_df, palette='Set2')
    plt.title(f'{attribute.capitalize()} vs Subscription')
    plt.xlabel('Subscription')
    plt.ylabel(attribute.capitalize())

plt.tight_layout()
plt.show()

# %%
import seaborn as sns

# Create age groups
bins = [0, 20, 30, 40, 50, 60, 70, 80, 90, 100]
labels = ['0-19', '20-29', '30-39', '40-49', '50-59', '60-69', '70-79', '80-89', '90-100']
final_df['age_group'] = pd.cut(final_df['age'], bins=bins, labels=labels, right=False)

# Calculate the count of subscriptions (yes and no) for each combination of education and age group
subscription_counts = final_df.pivot_table(values='y', index='education', columns='age_group', aggfunc='count').fillna(0)

# Plot the combined heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(subscription_counts, annot=True, cmap=sns.diverging_palette(240, 10, as_cmap=True), fmt='.0f')
plt.title('Subscription Count by Education Level and Age Group')
plt.xlabel('Age Group')
plt.ylabel('Education Level')
plt.show()

# %%
data_subset = final_df[['job', 'y']]

# Count occurrences of each combination of job, loan, and subscription
job_loan_subscription_counts = data_subset.groupby(['job', 'y']).size().unstack(fill_value=0)

# Plotting the horizontal stacked bar plot
plt.figure(figsize=(10, 12))
job_loan_subscription_counts.plot(kind='barh', stacked=True, colormap='Paired')

# Adding labels and title
plt.title('Impact of Job on Subscription')
plt.xlabel('Count')
plt.ylabel('Job Type')
plt.legend(title='Subscription', labels=['No', 'Yes'])

plt.show()

# %%
data_subset = final_df[['education', 'y']]

# Count occurrences of each combination of job, loan, and subscription
job_loan_subscription_counts = data_subset.groupby(['education', 'y']).size().unstack(fill_value=0)

# Plotting the horizontal stacked bar plot
plt.figure(figsize=(8, 6))
job_loan_subscription_counts.plot(kind='barh', stacked=True, colormap='Paired')

# Adding labels and title
plt.title('Impact of Education on Subscription')
plt.xlabel('Count')
plt.ylabel('Education Type')
plt.legend(title='Subscription', labels=['No', 'Yes'])

plt.show()

# %%
data_subset = final_df[['housing', 'loan', 'y']]

# Count occurrences of each combination of job, loan, and subscription
job_loan_subscription_counts = data_subset.groupby(['housing', 'loan', 'y']).size().unstack(fill_value=0)

# Plotting the horizontal stacked bar plot
plt.figure(figsize=(8, 6))
job_loan_subscription_counts.plot(kind='barh', stacked=True, colormap='Paired')

# Adding labels and title
plt.title('Impact of Housing and Loab on Subscription')
plt.xlabel('Count')
plt.ylabel('Housing and Loan Type')
plt.legend(title='Subscription', labels=['No', 'Yes'])

plt.show()

# %%
final_df.head()
# Out:
#    age          job  marital          education default housing loan  \
# 0   30  blue-collar  married           basic.9y      no     yes   no
# 1   39     services   single        high.school      no      no   no
# 2   25     services  married        high.school      no     yes   no
# 3   38     services  married           basic.9y      no     yes   no
# 4   47       admin.  married  university.degree      no     yes   no
#
#      contact month day_of_week  ...  pdays  previous     poutcome  \
# 0   cellular   may         fri  ...    999         0  nonexistent
# 1  telephone   may         fri  ...    999         0  nonexistent
# 2  telephone   jun         wed  ...    999         0  nonexistent
# 3  telephone   jun         fri  ...    999         0  nonexistent
# 4   cellular   nov         mon  ...    999         0  nonexistent
#
#    emp.var.rate cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y  \
# 0          -1.8         92.893          -46.2      1.313       5099.1  no
# 1           1.1         93.994          -36.4      4.855       5191.0  no
# 2           1.4         94.465          -41.8      4.962       5228.1  no
# 3           1.4         94.465          -41.8      4.959       5228.1  no
# 4          -0.1         93.200          -42.0      4.191       5195.8  no
#
#    age_group
# 0      30-39
# 1      30-39
# 2      20-29
# 3      30-39
# 4      40-49
#
# [5 rows x 22 columns]

# %%
 #Check summary statistics
summary = final_df.describe()
print(summary)
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41176.00000  41176.000000  41176.000000  41176.000000  41176.000000
# mean      40.02380    258.315815      2.567879    962.464810      0.173013
# std       10.42068    259.305321      2.770318    186.937102      0.494964
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41176.000000    41176.000000   41176.000000  41176.000000  41176.000000
# mean       0.081922       93.575720     -40.502863      3.621293   5167.034870
# std        1.570883        0.578839       4.627860      1.734437     72.251364
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %% [markdown]
# **Feature Engineering**

# %% [markdown]
# **Transformation of positively skewed plot**

# %%
from scipy.stats import skew

# Check skewness of each numeric variable
skewness = numerical_df.apply(skew)
print("Skewness before transformation:\n", skewness)

# Identify variables with skewness > 1
high_skew_columns = skewness[skewness > 1].index.tolist()
print("Variables with skewness > 1:", high_skew_columns)
# Out:
# Skewness before transformation:
#  age               0.784532
# duration          3.262689
# campaign          4.761871
# pdays            -4.921207
# previous          3.831256
# emp.var.rate     -0.724034
# cons.price.idx   -0.230844
# cons.conf.idx     0.302865
# euribor3m        -0.709168
# nr.employed      -1.044279
# dtype: float64
# Variables with skewness > 1: ['duration', 'campaign', 'previous']

# %%
# Apply square-root transformation for count data and log transformation for size data
for col in high_skew_columns:
    if col in ['duration', 'campaign', 'previous']:
        final_df[f'{col}_sqrt'] = np.sqrt(final_df[col])


# Check skewness after transformation
transformed_skewness = final_df[[f'{col}_sqrt' for col in high_skew_columns if f'{col}_sqrt' in final_df.columns] +
                          [f'{col}_log' for col in high_skew_columns if f'{col}_log' in final_df.columns]].apply(skew)
print("Skewness after transformation:\n", transformed_skewness)
# Out:
# Skewness after transformation:
#  duration_sqrt    1.199372
# campaign_sqrt    2.168338
# previous_sqrt    2.388152
# dtype: float64

# %% [markdown]
# **Creating New Features**

# %% [markdown]
# **Binning of age features**

# %%
bins = [0, 30, 40, 50, 60, 100]
labels = ['<30', '30-40', '40-50', '50-60', '60+']
final_df['age_group'] = pd.cut(final_df['age'], bins=bins, labels=labels)

# print(final_df.head())

# %% [markdown]
# **Total Contacts**

# %%
final_df['total_contacts'] = final_df['campaign'] + final_df['previous']
# print(final_df.head())

# %% [markdown]
# **Economic Indicators Ratio**

# %%
final_df['emp_var_rate_euribor3m_ratio'] = final_df['emp.var.rate'] / final_df['euribor3m']
final_df['cons_price_conf_idx_ratio'] = final_df['cons.price.idx'] / final_df['cons.conf.idx']

# %% [markdown]
# **Interaction between features**

# %%
# Interaction between number of employees and employment variation rate
final_df['nr_employed_emp_var_rate'] = final_df['nr.employed'] * final_df['emp.var.rate']

# Interaction between number of employees and consumer price index
final_df['nr_employed_cons_price_idx'] = final_df['nr.employed'] * final_df['cons.price.idx']
print(final_df.head())
# Out:
#    age          job  marital          education default housing loan  \
# 0   30  blue-collar  married           basic.9y      no     yes   no
# 1   39     services   single        high.school      no      no   no
# 2   25     services  married        high.school      no     yes   no
# 3   38     services  married           basic.9y      no     yes   no
# 4   47       admin.  married  university.degree      no     yes   no
#
#      contact month day_of_week  ...   y  age_group  duration_sqrt  \
# 0   cellular   may         fri  ...  no        <30      22.068076
# 1  telephone   may         fri  ...  no      30-40      18.601075
# 2  telephone   jun         wed  ...  no        <30      15.066519
# 3  telephone   jun         fri  ...  no      30-40       4.123106
# 4   cellular   nov         mon  ...  no      40-50       7.615773
#
#    campaign_sqrt previous_sqrt  total_contacts  emp_var_rate_euribor3m_ratio  \
# 0       1.414214           0.0               2                     -1.370906
# 1       2.000000           0.0               4                      0.226571
# 2       1.000000           0.0               1                      0.282144
# 3       1.732051           0.0               3                      0.282315
# 4       1.000000           0.0               1                     -0.023861
#
#    cons_price_conf_idx_ratio  nr_employed_emp_var_rate  \
# 0                  -2.010671                  -9178.38
# 1                  -2.582253                   5710.10
# 2                  -2.259928                   7319.34
# 3                  -2.259928                   7319.34
# 4                  -2.219048                   -519.58
#
#    nr_employed_cons_price_idx
# 0                 473670.6963
# 1                 487922.8540
# 2                 493872.4665
# 3                 493872.4665
# 4                 484248.5600
#
# [5 rows x 30 columns]

# %% [markdown]
# **Normalization**

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

# Fit and transform the numerical columns
final_df[numerical_columns] = scaler.fit_transform(final_df[numerical_columns])

# Display the normalized dataframe
print(final_df)
# Out:
#             age          job  marital            education default housing  \
# 0      0.160494  blue-collar  married             basic.9y      no     yes
# 1      0.271605     services   single          high.school      no      no
# 2      0.098765     services  married          high.school      no     yes
# 3      0.259259     services  married             basic.9y      no     yes
# 4      0.370370       admin.  married    university.degree      no     yes
# ...         ...          ...      ...                  ...     ...     ...
# 45301  0.148148   unemployed   single             basic.4y      no     yes
# 45302  0.691358      retired  married  professional.course      no     yes
# 45304  0.481481      retired  married    university.degree      no     yes
# 45305  0.333333   technician  married  professional.course      no      no
# 45306  0.703704      retired  married  professional.course      no     yes
#
#       loan    contact month day_of_week  ...    y  age_group  duration_sqrt  \
# 0       no   cellular   may         fri  ...   no        <30      22.068076
# 1       no  telephone   may         fri  ...   no      30-40      18.601075
# 2       no  telephone   jun         wed  ...   no        <30      15.066519
# 3       no  telephone   jun         fri  ...   no      30-40       4.123106
# 4       no   cellular   nov         mon  ...   no      40-50       7.615773
# ...    ...        ...   ...         ...  ...  ...        ...            ...
# 45301   no   cellular   nov         fri  ...   no        <30      10.583005
# 45302   no   cellular   nov         fri  ...  yes        60+      18.275667
# 45304   no   cellular   nov         fri  ...   no      50-60      13.747727
# 45305   no   cellular   nov         fri  ...  yes      40-50      21.023796
# 45306   no   cellular   nov         fri  ...   no        60+      15.459625
#
#        campaign_sqrt previous_sqrt  total_contacts  \
# 0           1.414214           0.0               2
# 1           2.000000           0.0               4
# 2           1.000000           0.0               1
# 3           1.732051           0.0               3
# 4           1.000000           0.0               1
# ...              ...           ...             ...
# 45301       1.000000           1.0               2
# 45302       1.000000           0.0               1
# 45304       1.414214           0.0               2
# 45305       1.000000           0.0               1
# 45306       1.732051           1.0               4
#
#        emp_var_rate_euribor3m_ratio  cons_price_conf_idx_ratio  \
# 0                         -1.370906                  -2.010671
# 1                          0.226571                  -2.582253
# 2                          0.282144                  -2.259928
# 3                          0.282315                  -2.259928
# 4                         -0.023861                  -2.219048
# ...                             ...                        ...
# 45301                     -1.070039                  -1.865492
# 45302                     -1.070039                  -1.865492
# 45304                     -1.070039                  -1.865492
# 45305                     -1.070039                  -1.865492
# 45306                     -1.070039                  -1.865492
#
#        nr_employed_emp_var_rate  nr_employed_cons_price_idx
# 0                      -9178.38                 473670.6963
# 1                       5710.10                 487922.8540
# 2                       7319.34                 493872.4665
# 3                       7319.34                 493872.4665
# 4                       -519.58                 484248.5600
# ...                         ...                         ...
# 45301                  -5459.96                 470385.4812
# 45302                  -5459.96                 470385.4812
# 45304                  -5459.96                 470385.4812
# 45305                  -5459.96                 470385.4812
# 45306                  -5459.96                 470385.4812
#
# [41176 rows x 30 columns]

# %%
print(final_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41176 entries, 0 to 45306
# Data columns (total 30 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   age                           41176 non-null  float64
#  1   job                           41176 non-null  object
#  2   marital                       41176 non-null  object
#  3   education                     41176 non-null  object
#  4   default                       41176 non-null  object
#  5   housing                       41176 non-null  object
#  6   loan                          41176 non-null  object
#  7   contact                       41176 non-null  object
#  8   month                         41176 non-null  object
#  9   day_of_week                   41176 non-null  object
#  10  duration                      41176 non-null  float64
#  11  campaign                      41176 non-null  float64
#  12  pdays                         41176 non-null  float64
#  13  previous                      41176 non-null  float64
#  14  poutcome                      41176 non-null  object
#  15  emp.var.rate                  41176 non-null  float64
#  16  cons.price.idx                41176 non-null  float64
#  17  cons.conf.idx                 41176 non-null  float64
#  18  euribor3m                     41176 non-null  float64
#  19  nr.employed                   41176 non-null  float64
#  20  y                             41176 non-null  object
#  21  age_group                     41176 non-null  category
#  22  duration_sqrt                 41176 non-null  float64
#  23  campaign_sqrt                 41176 non-null  float64
#  24  previous_sqrt                 41176 non-null  float64
#  25  total_contacts                41176 non-null  int64
#  26  emp_var_rate_euribor3m_ratio  41176 non-null  float64
#  27  cons_price_conf_idx_ratio     41176 non-null  float64
#  28  nr_employed_emp_var_rate      41176 non-null  float64
#  29  nr_employed_cons_price_idx    41176 non-null  float64
# dtypes: category(1), float64(17), int64(1), object(11)
# memory usage: 10.5+ MB
# None

# %% [markdown]
# **Dropping redundant columns**

# %%
def find_and_remove_redundant_columns(df):
    redundant_columns = set()
    suffixes = ['_ratio', '_sqrt']

    # Identify original columns that have corresponding transformed columns
    for suffix in suffixes:
        for col in df.columns:
            if col.endswith(suffix):
                base_col = col.replace(suffix, '')
                if base_col in df.columns:
                    redundant_columns.add(base_col)

    # Create a new DataFrame excluding the redundant columns
    df_cleaned = final_df.drop(columns=redundant_columns)

    return df_cleaned, list(redundant_columns)

# Example usage
df_cleaned, redundant_columns = find_and_remove_redundant_columns(final_df)
df = df_cleaned.copy()
print("Redundant columns:", redundant_columns)
# Out:
# Redundant columns: ['previous', 'campaign', 'duration']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41176 entries, 0 to 45306
# Data columns (total 27 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   age                           41176 non-null  float64
#  1   job                           41176 non-null  object
#  2   marital                       41176 non-null  object
#  3   education                     41176 non-null  object
#  4   default                       41176 non-null  object
#  5   housing                       41176 non-null  object
#  6   loan                          41176 non-null  object
#  7   contact                       41176 non-null  object
#  8   month                         41176 non-null  object
#  9   day_of_week                   41176 non-null  object
#  10  pdays                         41176 non-null  float64
#  11  poutcome                      41176 non-null  object
#  12  emp.var.rate                  41176 non-null  float64
#  13  cons.price.idx                41176 non-null  float64
#  14  cons.conf.idx                 41176 non-null  float64
#  15  euribor3m                     41176 non-null  float64
#  16  nr.employed                   41176 non-null  float64
#  17  y                             41176 non-null  object
#  18  age_group                     41176 non-null  category
#  19  duration_sqrt                 41176 non-null  float64
#  20  campaign_sqrt                 41176 non-null  float64
#  21  previous_sqrt                 41176 non-null  float64
#  22  total_contacts                41176 non-null  int64
#  23  emp_var_rate_euribor3m_ratio  41176 non-null  float64
#  24  cons_price_conf_idx_ratio     41176 non-null  float64
#  25  nr_employed_emp_var_rate      41176 non-null  float64
#  26  nr_employed_cons_price_idx    41176 non-null  float64
# dtypes: category(1), float64(14), int64(1), object(11)
# memory usage: 9.5+ MB

# %%
df = df.drop(df.columns[12:17], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41176 entries, 0 to 45306
# Data columns (total 22 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   age                           41176 non-null  float64
#  1   job                           41176 non-null  object
#  2   marital                       41176 non-null  object
#  3   education                     41176 non-null  object
#  4   default                       41176 non-null  object
#  5   housing                       41176 non-null  object
#  6   loan                          41176 non-null  object
#  7   contact                       41176 non-null  object
#  8   month                         41176 non-null  object
#  9   day_of_week                   41176 non-null  object
#  10  pdays                         41176 non-null  float64
#  11  poutcome                      41176 non-null  object
#  12  y                             41176 non-null  object
#  13  age_group                     41176 non-null  category
#  14  duration_sqrt                 41176 non-null  float64
#  15  campaign_sqrt                 41176 non-null  float64
#  16  previous_sqrt                 41176 non-null  float64
#  17  total_contacts                41176 non-null  int64
#  18  emp_var_rate_euribor3m_ratio  41176 non-null  float64
#  19  cons_price_conf_idx_ratio     41176 non-null  float64
#  20  nr_employed_emp_var_rate      41176 non-null  float64
#  21  nr_employed_cons_price_idx    41176 non-null  float64
# dtypes: category(1), float64(9), int64(1), object(11)
# memory usage: 8.0+ MB
